# %%
def list_to_string(items):
    # Fall: leere Liste
    if not items:
        return ""
    
    # Fall: nur ein Element
    if len(items) == 1:
        return items[0]
    
    # Allgemeiner Fall
    return ", ".join(items[:-1]) + ", and " + items[-1]


# Tests
spam = ['apples', 'bananas', 'tofu', 'cats']
print(list_to_string(spam))          # apples, bananas, tofu, and cats

print(list_to_string([]))            # "" (leerer String)
print(list_to_string(['apples']))    # apples
print(list_to_string(['apples', 'bananas']))  # apples, and bananas
# Out:
# apples, bananas, tofu, and cats
#
# apples
# apples, and bananas

# %%
import random

numberOfStreaks = 0

for experimentNumber in range(10000):
    # Liste mit 100 zufälligen Münzwürfen erzeugen
    flips = []
    for i in range(100):
        if random.randint(0, 1) == 0:
            flips.append('H')
        else:
            flips.append('T')

    # Prüfen, ob ein streak von 6 gleichen Werten vorkommt
    streak = 1
    for i in range(1, len(flips)):
        if flips[i] == flips[i - 1]:
            streak += 1
            if streak == 6:
                numberOfStreaks += 1
                break
        else:
            streak = 1

print('Chance of streak: %s%%' % (numberOfStreaks / 100))
# Out:
# Chance of streak: 80.65%

# %%
stuff = {'rope': 1, 'torch': 6, 'gold coin': 42, 'dagger': 1, 'arrow': 12}
morestuff = {'apple': 2, 'banana':1, 'kiwi':3}

def displayInventory(inventory):
    print("Inventory:")
    item_total = 0
    for k, v in inventory.items():
        print(str(v) + " " + k)
        item_total += v
    print("Total number of items: " + str(item_total))

displayInventory(stuff)
displayInventory(morestuff)
# Out:
# Inventory:
# 1 rope
# 6 torch
# 42 gold coin
# 1 dagger
# 12 arrow
# Total number of items: 62
# Inventory:
# 2 apple
# 1 banana
# 3 kiwi
# Total number of items: 6

# %%
def addToInventory(inventory, addedItems):
    for item in addedItems:
        if item in inventory:
            inventory[item] += 1
        else:
            inventory[item] = 1
    return inventory


def displayInventory(inventory):
    print("Inventory:")
    item_total = 0
    for k, v in inventory.items():
        print(str(v) + " " + k)
        item_total += v
    print("Total number of items: " + str(item_total))


inv = {'gold coin': 42, 'rope': 1}
dragonLoot = ['gold coin', 'dagger', 'gold coin', 'gold coin', 'ruby']

inv = addToInventory(inv, dragonLoot)
displayInventory(inv)
# Out:
# Inventory:
# 45 gold coin
# 1 rope
# 1 dagger
# 1 ruby
# Total number of items: 48
